# %%
from packages import *
import EOFsfunction 
import Soil_moisture_weights

# %%
data_EX1 = xr.open_dataset('/scratch/ksilwimba/Data/US_data/CLM5_experiment_1_US_1980-2010.nc')
data_EX2 = xr.open_dataset('/scratch/ksilwimba/Data/US_data/CLM5_experiment_2_US_1980-2010.nc')
data_EX3 = xr.open_dataset('/scratch/ksilwimba/Data/US_data/CLM5_experiment_3_US_1980-2010.nc')
data_EX4a = xr.open_dataset('/scratch/ksilwimba/Data/US_data/CLM5_experiment_4a_US_1980-2010.nc')
data_EX4b = xr.open_dataset('/scratch/ksilwimba/Data/US_data/CLM5_experiment_4b_US_1980-2010.nc')
data_EX4c = xr.open_dataset('/scratch/ksilwimba/Data/US_data/CLM5_experiment_4c_US_1980-2010.nc')
data_EX4d = xr.open_dataset('/scratch/ksilwimba/Data/US_data/CLM5_experiment_4d_US_1980-2010.nc')

# %%
#data = data_EX4d.mrlsl.groupby('time.season').mean('time')

# %% [markdown]
# ### Water Content per Unit Area of Soil Layer

# %%
Exp1_mrlsl = data_EX1['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.month').mean('time').isel()
Exp2_mrlsl = data_EX2['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.month').mean('time').isel()
Exp3_mrlsl = data_EX3['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.month').mean('time').isel()
Exp4a_mrlsl = data_EX4a['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.month').mean('time').isel()
Exp4b_mrlsl = data_EX4b['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.month').mean('time').isel()
Exp4c_mrlsl = data_EX4c['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.month').mean('time').isel()
Exp4d_mrlsl = data_EX4d['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.month').mean('time').isel()

# %%
mrlsl_EX1 = np.mean(np.reshape(Exp1_mrlsl[:,0,:], (12,140)), axis = 1)
mrlsl_EX2 = np.mean(np.reshape(Exp2_mrlsl[:,0,:], (12,140)), axis = 1)
mrlsl_EX3 = np.mean(np.reshape(Exp3_mrlsl[:,0,:], (12,140)), axis = 1)
mrlsl_EX4a = np.mean(np.reshape(Exp4a_mrlsl[:,0,:], (12,140)), axis = 1)
mrlsl_EX4b = np.mean(np.reshape(Exp4b_mrlsl[:,0,:], (12,140)), axis = 1)
mrlsl_EX4c = np.mean(np.reshape(Exp4c_mrlsl[:,0,:], (12,140)), axis = 1)
mrlsl_EX4d = np.mean(np.reshape(Exp4d_mrlsl[:,0,:], (12,140)), axis = 1)

# %% [markdown]
# ### Soil Temperature

# %%
Exp1_tsl = data_EX1['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.month').mean('time').isel()
Exp2_tsl = data_EX2['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.month').mean('time').isel()
Exp3_tsl = data_EX3['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.month').mean('time').isel()
Exp4a_tsl = data_EX4a['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.month').mean('time').isel()
Exp4b_tsl = data_EX4b['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.month').mean('time').isel()
Exp4c_tsl = data_EX4c['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.month').mean('time').isel()
Exp4d_tsl = data_EX4d['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.month').mean('time').isel()

# %%
tsl_EX1 = np.mean(np.reshape(Exp1_tsl[:,0,:], (12,140)), axis = 1)
tsl_EX2 = np.mean(np.reshape(Exp2_tsl[:,0,:], (12,140)), axis = 1)
tsl_EX3 = np.mean(np.reshape(Exp3_tsl[:,0,:], (12,140)), axis = 1)
tsl_EX4a = np.mean(np.reshape(Exp4a_tsl[:,0,:], (12,140)), axis = 1)
tsl_EX4b = np.mean(np.reshape(Exp4b_tsl[:,0,:], (12,140)), axis = 1)
tsl_EX4c = np.mean(np.reshape(Exp4c_tsl[:,0,:], (12,140)), axis = 1)
tsl_EX4d = np.mean(np.reshape(Exp4d_tsl[:,0,:], (12,140)), axis = 1)

# %% [markdown]
# ### Surface Snow Amount

# %%
snm_Exp1 = data_EX1['snm'].groupby('time.month').mean('time').isel()
snm_Exp2 = data_EX2['snm'].groupby('time.month').mean('time').isel()
snm_Exp3 = data_EX3['snm'].groupby('time.month').mean('time').isel()
snm_Exp4a = data_EX4a['snm'].groupby('time.month').mean('time').isel()
snm_Exp4b = data_EX4b['snm'].groupby('time.month').mean('time').isel()
snm_Exp4c = data_EX4c['snm'].groupby('time.month').mean('time').isel()
snm_Exp4d = data_EX4d['snm'].groupby('time.month').mean('time').isel()

# %%
snm_EX1 = np.mean(np.reshape(snm_Exp1[:,0,:], (12,140)), axis = 1)
snm_EX2 = np.mean(np.reshape(snm_Exp2[:,0,:], (12,140)), axis = 1)
snm_EX3 = np.mean(np.reshape(snm_Exp3[:,0,:], (12,140)), axis = 1)
snm_EX4a = np.mean(np.reshape(snm_Exp4a[:,0,:], (12,140)), axis = 1)
snm_EX4b = np.mean(np.reshape(snm_Exp4b[:,0,:], (12,140)), axis = 1)
snm_EX4c = np.mean(np.reshape(snm_Exp4c[:,0,:], (12,140)), axis = 1)
snm_EX4d = np.mean(np.reshape(snm_Exp4d[:,0,:], (12,140)), axis = 1)

# %% [markdown]
# ### Total Evapotranspiration

# %%
Exp1_et = data_EX1['et'].groupby('time.month').mean('time').isel()
Exp2_et = data_EX2['et'].groupby('time.month').mean('time').isel()
Exp3_et = data_EX3['et'].groupby('time.month').mean('time').isel()
Exp4a_et = data_EX4a['et'].groupby('time.month').mean('time').isel()
Exp4b_et = data_EX4b['et'].groupby('time.month').mean('time').isel()
Exp4c_et = data_EX4c['et'].groupby('time.month').mean('time').isel()
Exp4d_et = data_EX4d['et'].groupby('time.month').mean('time').isel()

# %%
et_EX1 = np.mean(np.reshape(Exp1_et[:,0,:], (12,140)), axis = 1)
et_EX2 = np.mean(np.reshape(Exp2_et[:,0,:], (12,140)), axis = 1)
et_EX3 = np.mean(np.reshape(Exp3_et[:,0,:], (12,140)), axis = 1)
et_EX4a = np.mean(np.reshape(Exp4a_et[:,0,:], (12,140)), axis = 1)
et_EX4b = np.mean(np.reshape(Exp4b_et[:,0,:], (12,140)), axis = 1)
et_EX4c = np.mean(np.reshape(Exp4c_et[:,0,:], (12,140)), axis = 1)
et_EX4d = np.mean(np.reshape(Exp4d_et[:,0,:], (12,140)), axis = 1)

# %%
# 1x3 plot
months = np.arange(1,13)

fig = plt.figure(figsize=(15,3))

ax1 = fig.add_subplot(1,4,1)
ax1.bar(months, mrlsl_EX1, color='forestgreen')
ax1.set_xticks(np.arange(1,13))
ax1.set_xticklabels(['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])
ax1.set_ylabel('Soil Moisture ')
#ax1.set_ylim(0, 140)
ax1.set_title('Soil Moisture ')

ax2 = fig.add_subplot(1,4,2)
ax2.bar(months,tsl_EX1, color='crimson')
ax2.set_xticks(np.arange(1,13))
ax2.set_xticklabels(['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])
ax2.set_ylabel('Soil Temperture')
#ax2.set_ylim(0, 140)
ax2.set_title('Soil Temperture')

ax3 = fig.add_subplot(1,4,3)
ax3.bar(months, snm_EX1, color='blueviolet')
ax3.set_xticks(np.arange(1,13))
ax3.set_xticklabels(['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])
ax3.set_ylabel('Snow Melt ')
#ax3.set_ylim(0, 140)
ax3.set_title('Snow Melt ')

ax4 = fig.add_subplot(1,4,4)
ax4.bar(months, et_EX1, color='orange')
ax4.set_xticks(np.arange(1,13))
ax4.set_xticklabels(['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])
ax4.set_ylabel('Evapotranspiration')
#ax4.set_ylim(0, 140)
ax4.set_title('Evapotranspiration')

fig.tight_layout()

# %%
fig = plt.figure(figsize = (11,10))
plt.subplot(2,2,1)
sns.distplot(et_EX1, hist=False, kde=True, 
             bins=int(5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'shade': True,'linewidth': 4})
plt.xlabel("et [kgm$^{-2}s^{-1}$]", fontweight='bold', fontsize=10)
plt.title("Total Evapotranspiration ",fontweight='bold', fontsize=11 )
plt.ylabel("Density", fontweight='bold', fontsize=10)

plt.subplot(2,2,2)
sns.distplot(snm_EX1, hist=False, kde=True, 
             bins=int(5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'shade': True,'linewidth': 4})
plt.xlabel("snm [kgm$^{-2}$]", fontweight='bold', fontsize=10)
plt.title("Surface Snow Amount",fontweight='bold', fontsize=11 )
plt.ylabel("Density", fontweight='bold', fontsize=10)

plt.subplot(2,2,3)
sns.distplot(tsl_EX1, hist=False, kde=True, 
             bins=int(5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'shade': True,'linewidth': 4})
plt.xlabel("tsl [K]", fontweight='bold', fontsize=10)
plt.title("Soil Temperature ",fontweight='bold', fontsize=11 )
plt.ylabel("Density", fontweight='bold', fontsize=10)

plt.subplot(2,2,4)
sns.distplot(mrlsl_EX1, hist=False, kde=True, 
             bins=int(5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'shade': True,'linewidth': 4})
plt.xlabel("mrlsl [kgm$^{-2}$]", fontweight='bold', fontsize=10)
plt.title("Soil Moisture",fontweight='bold', fontsize=11 )
plt.ylabel("Density", fontweight='bold', fontsize=10)
plt.show()

# %%
# fig, axes = plt.subplots(nrows=2, ncols=3, sharex=False, sharey='row', figsize=(10, 8))
# labels = in_vars
# axes = axes.flatten()
# for i in range(ndim):
#     ax = axes[i]
#     ax.hist(et_EX1, bins=20)
#     ax.set_title(labels[i])

# axes[0].set_ylabel("counts")
# axes[3].set_ylabel("counts");

# #plt.savefig("inputdata_rand_dists.pdf")

# %%
fig = plt.figure(figsize = (15,10))

plt.subplot(2,2,1)
plt.plot(mrlsl_EX1.month, mrlsl_EX1, label="Exp-1 SP-MIP Params",linewidth=2,linestyle='dashed',   marker="o")
plt.plot(mrlsl_EX2.month, mrlsl_EX2, linewidth=2,label="Exp-2 Soil Textural Properties Params",linestyle='dashed',   marker="o")
plt.plot(mrlsl_EX3.month, mrlsl_EX3, linewidth=2,label="Exp-3-Control run",linestyle='dashed',  marker="o")
plt.plot(mrlsl_EX4a.month, mrlsl_EX4a, linewidth=2, label="Exp-4a-Loamy Sand",linestyle='dashed', marker="o")
plt.plot(mrlsl_EX4b.month, mrlsl_EX4b, linewidth=2,label="Exp-4b-Loam",linestyle='dashed', marker="o")
plt.plot(mrlsl_EX4c.month, mrlsl_EX4c, linewidth=2,label="Exp-4c-Clay",linestyle='dashed', marker="o")
plt.plot(mrlsl_EX4d.month, mrlsl_EX4d, linewidth=2, label="Exp-4d-Silt",linestyle='dashed',marker="o")
plt.ylabel("Soil Moisture [kgm$^{-2}$]", fontweight='bold', fontsize=12)
plt.xticks(np.arange(12)+1, ['J','F','M','A','M','J','J','A','S','O','N','D'],fontweight='bold', fontsize=12)
plt.title("Soil Moisture",fontweight='bold', fontsize=12 )
#plt.xlabel('Month',fontweight='bold', fontsize=12)
plt.minorticks_on()
#plt.grid()

plt.subplot(2,2,2)
plt.plot(snm_EX1.month, snm_EX1, label="Exp-1 SP-MIP Params",linewidth=2,linestyle='dashed',   marker="o")
plt.plot(snm_EX2.month, snm_EX2, linewidth=2,label="Exp-2 Soil Textural Properties Params",linestyle='dashed',   marker="o")
plt.plot(snm_EX3.month, snm_EX3, linewidth=2,label="Exp-3-Control run",linestyle='dashed',  marker="o")
plt.plot(snm_EX4a.month, snm_EX4a, linewidth=2, label="Exp-4a-Loamy Sand",linestyle='dashed', marker="o")
plt.plot(snm_EX4b.month, snm_EX4b, linewidth=2,label="Exp-4b-Loam",linestyle='dashed', marker="o")
plt.plot(snm_EX4c.month, snm_EX4c, linewidth=2,label="Exp-4c-Clay",linestyle='dashed', marker="o")
plt.plot(snm_EX4d.month, snm_EX4d, linewidth=2, label="Exp-4d-Silt",linestyle='dashed',marker="o")
plt.ylabel("Surface Snow Amount [kgm$^{-2}$]", fontweight='bold', fontsize=12)
plt.xticks(np.arange(12)+1, ['J','F','M','A','M','J','J','A','S','O','N','D'],fontweight='bold', fontsize=12)
plt.title("Surface Snow Amount",fontweight='bold', fontsize=12 )
#plt.xlabel('Month',fontweight='bold', fontsize=12)
plt.minorticks_on()
#plt.grid()

plt.subplot(2,2,3)
plt.plot(tsl_EX1.month, tsl_EX1, label="Exp-1 SP-MIP Params",linewidth=2,linestyle='dashed',   marker="o")
plt.plot(tsl_EX2.month, tsl_EX2, linewidth=2,label="Exp-2 Soil Textural Properties Params",linestyle='dashed',   marker="o")
plt.plot(tsl_EX3.month, tsl_EX3, linewidth=2,label="Exp-3-Control run",linestyle='dashed',  marker="o")
plt.plot(tsl_EX4a.month, tsl_EX4a, linewidth=2, label="Exp-4a-Loamy Sand",linestyle='dashed', marker="o")
plt.plot(tsl_EX4b.month, tsl_EX4b, linewidth=2,label="Exp-4b-Loam",linestyle='dashed', marker="o")
plt.plot(tsl_EX4c.month, tsl_EX4c, linewidth=2,label="Exp-4c-Clay",linestyle='dashed', marker="o")
plt.plot(tsl_EX4d.month, tsl_EX4d, linewidth=2, label="Exp-4d-Silt",linestyle='dashed',marker="o")
plt.ylabel("Soil Temperature [K]", fontweight='bold', fontsize=12)
plt.xticks(np.arange(12)+1, ['J','F','M','A','M','J','J','A','S','O','N','D'],fontweight='bold', fontsize=12)
plt.title("Soil Temperature",fontweight='bold', fontsize=12 )
plt.xlabel('Month',fontweight='bold', fontsize=12)
plt.minorticks_on()
#plt.grid()

plt.subplot(2,2,4)
plt.plot(et_EX1.month, et_EX1, label="Exp-1 Identical soil parameters maps",linewidth=2,linestyle='dashed',   marker="o")
plt.plot(et_EX2.month, et_EX2, linewidth=2,label="Exp-2 Identical soil texture maps",linestyle='dashed',   marker="o")
plt.plot(et_EX3.month, et_EX3, linewidth=2,label="Exp-3 Default soil parameters maps",linestyle='dashed',  marker="o")
plt.plot(et_EX4a.month, et_EX4a, linewidth=2, label="Exp-4a-Loamy-Sand Spatially uniform soil parameters",linestyle='dashed', marker="o")
plt.plot(et_EX4b.month, et_EX4b, linewidth=2,label="Exp-4b-Loam Spatially uniform soil parameters",linestyle='dashed', marker="o")
plt.plot(et_EX4c.month, et_EX4c, linewidth=2,label="Exp-4c-Clay Spatially uniform soil parameters",linestyle='dashed', marker="o")
plt.plot(et_EX4d.month, et_EX4d, linewidth=2, label="Exp-4d-Silt Spatially uniform soil parameters",linestyle='dashed',marker="o")
plt.ylabel("Total Evapotranspiration [kgm$^{-2}s^{-1}$]",fontweight='bold', fontsize=12)
plt.xticks(np.arange(12)+1, ['J','F','M','A','M','J','J','A','S','O','N','D'],fontweight='bold', fontsize=12)
plt.title("Total Evapotranspiration",fontweight='bold',  fontsize=12 )
plt.xlabel('Month',fontweight='bold', fontsize=12)
plt.minorticks_on()
#plt.grid()

plt.suptitle('Annual Cycle from 1980-2011 Climatology',fontweight='bold',fontsize=17, y=.95)

plt.legend(loc='upper left', bbox_to_anchor=(-1.166, -0.15),fancybox=True, shadow=True, ncol=3)
plt.show()

# %% [markdown]
# ### Spatial Sasonal Cycles

# %%
sExp1_mrlsl = data_EX1['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.season').mean('time').isel()
sExp2_mrlsl = data_EX2['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.season').mean('time').isel()
sExp3_mrlsl = data_EX3['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.season').mean('time').isel()
sExp4a_mrlsl = data_EX4a['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.season').mean('time').isel()
sExp4b_mrlsl = data_EX4b['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.season').mean('time').isel()
sExp4c_mrlsl = data_EX4c['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.season').mean('time').isel()
sExp4d_mrlsl = data_EX4d['mrlsl'].sel(levsoi=slice(0,1)).mean('levsoi').groupby('time.season').mean('time').isel()

# %%
sExp1_tsl = data_EX1['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.season').mean('time').isel()
sExp2_tsl = data_EX2['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.season').mean('time').isel()
sExp3_tsl = data_EX3['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.season').mean('time').isel()
sExp4a_tsl = data_EX4a['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.season').mean('time').isel()
sExp4b_tsl = data_EX4b['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.season').mean('time').isel()
sExp4c_tsl = data_EX4c['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.season').mean('time').isel()
sExp4d_tsl = data_EX4d['tsl'].sel(levgrnd=slice(0,1)).mean('levgrnd').groupby('time.season').mean('time').isel()

# %%
sExp1_et = data_EX1['et'].groupby('time.season').mean('time').isel()
sExp2_et = data_EX2['et'].groupby('time.season').mean('time').isel()
sExp3_et = data_EX3['et'].groupby('time.season').mean('time').isel()
sExp4a_et = data_EX4a['et'].groupby('time.season').mean('time').isel()
sExp4b_et = data_EX4b['et'].groupby('time.season').mean('time').isel()
sExp4c_et = data_EX4c['et'].groupby('time.season').mean('time').isel()
sExp4d_et = data_EX4d['et'].groupby('time.season').mean('time').isel()

# %%
import cartopy.crs as ccrs

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,7], gridspec_kw={'wspace':.14, 'hspace':.23})
kwargs = {'format': '%.0f'} 
 
axs[0,0].set_title('a',fontweight='bold', fontsize=13, loc='left')
original1=axs[0,0].imshow(sExp1_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("Season DJF", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

axs[0,1].set_title('b', fontweight='bold',fontsize=13, loc='left')
original2=axs[0,1].imshow(sExp1_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("Season JJA", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

axs[0,2].set_title('c ',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,2].imshow(sExp1_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("Season MAM", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

axs[0,3].set_title('d',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,3].imshow(sExp1_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("Season SON", loc='center',fontweight='bold',size=13)
axs[0,3].grid()

cb =fig.colorbar(original2, cmap='BrBG', ax=axs[0,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.03)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')
################################# Soil Temperature ################################################################
 
axs[1,0].set_title('e',fontweight='bold', fontsize=13, loc='left')
original1=axs[1,0].imshow(sExp1_tsl[0,:,:].squeeze()-273 , cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[1,0].grid()

axs[1,1].set_title('f', fontweight='bold',fontsize=13, loc='left')
original21=axs[1,1].imshow(sExp1_tsl[1,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[1,1].grid()

axs[1,2].set_title('g',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,2].imshow(sExp1_tsl[2,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[1,2].grid()

axs[1,3].set_title('h',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,3].imshow(sExp1_tsl[3,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,3].set_title("SON", loc='right',fontweight='bold',size=13)
axs[1,3].grid()

cb =fig.colorbar(original21, cmap='RdBu_r', ax=axs[1,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.032)
cb.set_label('Soil Temperature [$^\circ$C]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

##########################################Total Evapotranspiration##############################################

axs[2,0].set_title('i',fontweight='bold', fontsize=13, loc='left')
original1=axs[2,0].imshow(sExp1_et[0,:,:].squeeze() , cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[2,0].grid()

axs[2,1].set_title('j', fontweight='bold',fontsize=13, loc='left')
original2=axs[2,1].imshow(sExp1_et[1,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[2,1].grid()

axs[2,2].set_title('k ',fontweight='bold', fontsize=13, loc='left')
original3=axs[2,2].imshow(sExp1_et[2,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[2,2].grid()

axs[2,3].set_title('l',fontweight='bold', fontsize=13, loc='left')
original33=axs[2,3].imshow(sExp1_et[3,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,3].set_title("SON", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original33,  cmap='terrain', ax=axs[2,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.035)
cb.set_label('Evapotransp. [kgm$^{-2}$s$^{-1}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

plt.suptitle('Exp1 Seasonal Cycle from 1980-2010 Climatology'"\n" "Identical Soil Parameter Maps",fontweight='bold',fontsize=14)


# cmap = plt.cm.terrain
# bounds = [-1, 2, 5, 7, 12, 15]
# norm = plt.colors.BoundaryNorm(bounds, cmap.N, extend='both')
# fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
#              cax=ax, orientation='horizontal', label='Some Units')
# ax = plt.subplot(projection=ccrs.PlateCarree())
# ax.coastlines("10m", color="r")
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,7], gridspec_kw={'wspace':.14, 'hspace':.23})
kwargs = {'format': '%.0f'} 
 
axs[0,0].set_title('a',fontweight='bold', fontsize=13, loc='left')
original1=axs[0,0].imshow(sExp2_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("Season DJF", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

axs[0,1].set_title('b', fontweight='bold',fontsize=13, loc='left')
original2=axs[0,1].imshow(sExp2_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("Season JJA", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

axs[0,2].set_title('c ',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,2].imshow(sExp2_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("Season MAM", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

axs[0,3].set_title('d',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,3].imshow(sExp2_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("Season SON", loc='center',fontweight='bold',size=13)
axs[0,3].grid()

cb =fig.colorbar(original2, cmap='BrBG', ax=axs[0,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.03)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')
################################# Soil Temperature ################################################################
 
axs[1,0].set_title('e',fontweight='bold', fontsize=13, loc='left')
original1=axs[1,0].imshow(sExp2_tsl[0,:,:].squeeze()-273 , cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[1,0].grid()

axs[1,1].set_title('f', fontweight='bold',fontsize=13, loc='left')
original21=axs[1,1].imshow(sExp2_tsl[1,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[1,1].grid()

axs[1,2].set_title('g',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,2].imshow(sExp2_tsl[2,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[1,2].grid()

axs[1,3].set_title('h',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,3].imshow(sExp2_tsl[3,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,3].set_title("SON", loc='right',fontweight='bold',size=13)
axs[1,3].grid()

cb =fig.colorbar(original21, cmap='RdBu_r', ax=axs[1,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.032)
cb.set_label('Soil Temperature [$^\circ$C]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

##########################################Total Evapotranspiration##############################################

axs[2,0].set_title('i',fontweight='bold', fontsize=13, loc='left')
original1=axs[2,0].imshow(sExp2_et[0,:,:].squeeze() , cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[2,0].grid()

axs[2,1].set_title('j', fontweight='bold',fontsize=13, loc='left')
original2=axs[2,1].imshow(sExp1_et[1,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[2,1].grid()

axs[2,2].set_title('k ',fontweight='bold', fontsize=13, loc='left')
original3=axs[2,2].imshow(sExp2_et[2,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[2,2].grid()

axs[2,3].set_title('l',fontweight='bold', fontsize=13, loc='left')
original33=axs[2,3].imshow(sExp2_et[3,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,3].set_title("SON", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original33,  cmap='terrain', ax=axs[2,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.035)
cb.set_label('Evapotransp. [kgm$^{-2}$s$^{-1}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

plt.suptitle('Exp2 Seasonal Cycle from 1980-2010 Climatology'"\n" "Identical Soil Texture Maps",fontweight='bold',fontsize=14)


# cmap = plt.cm.terrain
# bounds = [-1, 2, 5, 7, 12, 15]
# norm = plt.colors.BoundaryNorm(bounds, cmap.N, extend='both')
# fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
#              cax=ax, orientation='horizontal', label='Some Units')
# ax = plt.subplot(projection=ccrs.PlateCarree())
# ax.coastlines("10m", color="r")
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,7], gridspec_kw={'wspace':.14, 'hspace':.23})
kwargs = {'format': '%.0f'} 
 
axs[0,0].set_title('a',fontweight='bold', fontsize=13, loc='left')
original1=axs[0,0].imshow(sExp3_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("Season DJF", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

axs[0,1].set_title('b', fontweight='bold',fontsize=13, loc='left')
original2=axs[0,1].imshow(sExp3_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("Season JJA", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

axs[0,2].set_title('c ',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,2].imshow(sExp3_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("Season MAM", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

axs[0,3].set_title('d',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,3].imshow(sExp3_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("Season SON", loc='center',fontweight='bold',size=13)
axs[0,3].grid()

cb =fig.colorbar(original2, cmap='BrBG', ax=axs[0,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.03)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')
################################# Soil Temperature ################################################################
 
axs[1,0].set_title('e',fontweight='bold', fontsize=13, loc='left')
original1=axs[1,0].imshow(sExp3_tsl[0,:,:].squeeze()-273 , cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[1,0].grid()

axs[1,1].set_title('f', fontweight='bold',fontsize=13, loc='left')
original21=axs[1,1].imshow(sExp3_tsl[1,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[1,1].grid()

axs[1,2].set_title('g',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,2].imshow(sExp3_tsl[2,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[1,2].grid()

axs[1,3].set_title('h',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,3].imshow(sExp3_tsl[3,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,3].set_title("SON", loc='right',fontweight='bold',size=13)
axs[1,3].grid()

cb =fig.colorbar(original21, cmap='RdBu_r', ax=axs[1,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.032)
cb.set_label('Soil Temperature [$^\circ$C]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

##########################################Total Evapotranspiration##############################################

axs[2,0].set_title('i',fontweight='bold', fontsize=13, loc='left')
original1=axs[2,0].imshow(sExp3_et[0,:,:].squeeze() , cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[2,0].grid()

axs[2,1].set_title('j', fontweight='bold',fontsize=13, loc='left')
original2=axs[2,1].imshow(sExp3_et[1,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[2,1].grid()

axs[2,2].set_title('k ',fontweight='bold', fontsize=13, loc='left')
original3=axs[2,2].imshow(sExp3_et[2,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[2,2].grid()

axs[2,3].set_title('l',fontweight='bold', fontsize=13, loc='left')
original33=axs[2,3].imshow(sExp3_et[3,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,3].set_title("SON", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original33,  cmap='terrain', ax=axs[2,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.035)
cb.set_label('Evapotransp. [kgm$^{-2}$s$^{-1}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

plt.suptitle('Exp3 Seasonal Cycle from 1980-2010 Climatology'"\n" "Default Soil Parameter Maps",fontweight='bold',fontsize=14)


# cmap = plt.cm.terrain
# bounds = [-1, 2, 5, 7, 12, 15]
# norm = plt.colors.BoundaryNorm(bounds, cmap.N, extend='both')
# fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
#              cax=ax, orientation='horizontal', label='Some Units')
# ax = plt.subplot(projection=ccrs.PlateCarree())
# ax.coastlines("10m", color="r")
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,7], gridspec_kw={'wspace':.14, 'hspace':.23})
kwargs = {'format': '%.0f'} 
 
axs[0,0].set_title('a',fontweight='bold', fontsize=13, loc='left')
original1=axs[0,0].imshow(sExp4a_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("Season DJF", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

axs[0,1].set_title('b', fontweight='bold',fontsize=13, loc='left')
original2=axs[0,1].imshow(sExp4a_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("Season JJA", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

axs[0,2].set_title('c ',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,2].imshow(sExp4a_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("Season MAM", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

axs[0,3].set_title('d',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,3].imshow(sExp4a_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("Season SON", loc='center',fontweight='bold',size=13)
axs[0,3].grid()

cb =fig.colorbar(original2, cmap='BrBG', ax=axs[0,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.03)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')
################################# Soil Temperature ################################################################
 
axs[1,0].set_title('e',fontweight='bold', fontsize=13, loc='left')
original1=axs[1,0].imshow(sExp4a_tsl[0,:,:].squeeze()-273 , cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[1,0].grid()

axs[1,1].set_title('f', fontweight='bold',fontsize=13, loc='left')
original21=axs[1,1].imshow(sExp4a_tsl[1,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[1,1].grid()

axs[1,2].set_title('g',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,2].imshow(sExp4a_tsl[2,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[1,2].grid()

axs[1,3].set_title('h',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,3].imshow(sExp4a_tsl[3,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,3].set_title("SON", loc='right',fontweight='bold',size=13)
axs[1,3].grid()

cb =fig.colorbar(original21, cmap='RdBu_r', ax=axs[1,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.032)
cb.set_label('Soil Temperature [$^\circ$C]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

##########################################Total Evapotranspiration##############################################

axs[2,0].set_title('i',fontweight='bold', fontsize=13, loc='left')
original1=axs[2,0].imshow(sExp4a_et[0,:,:].squeeze() , cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[2,0].grid()

axs[2,1].set_title('j', fontweight='bold',fontsize=13, loc='left')
original2=axs[2,1].imshow(sExp4a_et[1,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[2,1].grid()

axs[2,2].set_title('k ',fontweight='bold', fontsize=13, loc='left')
original3=axs[2,2].imshow(sExp4a_et[2,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[2,2].grid()

axs[2,3].set_title('l',fontweight='bold', fontsize=13, loc='left')
original33=axs[2,3].imshow(sExp4a_et[3,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,3].set_title("SON", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original33,  cmap='terrain', ax=axs[2,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.035)
cb.set_label('Evapotransp. [kgm$^{-2}$s$^{-1}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

plt.suptitle('Exp4a-Loamy Seasonal Cycle from 1980-2010 Climatology'"\n" "Spatially Uniform Soil Parameters",fontweight='bold',fontsize=14)


# cmap = plt.cm.terrain
# bounds = [-1, 2, 5, 7, 12, 15]
# norm = plt.colors.BoundaryNorm(bounds, cmap.N, extend='both')
# fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
#              cax=ax, orientation='horizontal', label='Some Units')
# ax = plt.subplot(projection=ccrs.PlateCarree())
# ax.coastlines("10m", color="r")
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,7], gridspec_kw={'wspace':.14, 'hspace':.23})
kwargs = {'format': '%.0f'} 
 
axs[0,0].set_title('a',fontweight='bold', fontsize=13, loc='left')
original1=axs[0,0].imshow(sExp4b_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("Season DJF", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

axs[0,1].set_title('b', fontweight='bold',fontsize=13, loc='left')
original2=axs[0,1].imshow(sExp4b_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("Season JJA", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

axs[0,2].set_title('c ',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,2].imshow(sExp4b_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("Season MAM", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

axs[0,3].set_title('d',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,3].imshow(sExp4b_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("Season SON", loc='center',fontweight='bold',size=13)
axs[0,3].grid()

cb =fig.colorbar(original2, cmap='BrBG', ax=axs[0,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.03)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')
################################# Soil Temperature ################################################################
 
axs[1,0].set_title('e',fontweight='bold', fontsize=13, loc='left')
original1=axs[1,0].imshow(sExp4b_tsl[0,:,:].squeeze()-273 , cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[1,0].grid()

axs[1,1].set_title('f', fontweight='bold',fontsize=13, loc='left')
original21=axs[1,1].imshow(sExp4b_tsl[1,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[1,1].grid()

axs[1,2].set_title('g',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,2].imshow(sExp4b_tsl[2,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[1,2].grid()

axs[1,3].set_title('h',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,3].imshow(sExp4b_tsl[3,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,3].set_title("SON", loc='right',fontweight='bold',size=13)
axs[1,3].grid()

cb =fig.colorbar(original21, cmap='RdBu_r', ax=axs[1,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.032)
cb.set_label('Soil Temperature [$^\circ$C]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

##########################################Total Evapotranspiration##############################################

axs[2,0].set_title('i',fontweight='bold', fontsize=13, loc='left')
original1=axs[2,0].imshow(sExp4b_et[0,:,:].squeeze() , cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[2,0].grid()

axs[2,1].set_title('j', fontweight='bold',fontsize=13, loc='left')
original2=axs[2,1].imshow(sExp4b_et[1,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[2,1].grid()

axs[2,2].set_title('k ',fontweight='bold', fontsize=13, loc='left')
original3=axs[2,2].imshow(sExp4b_et[2,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[2,2].grid()

axs[2,3].set_title('l',fontweight='bold', fontsize=13, loc='left')
original33=axs[2,3].imshow(sExp4b_et[3,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,3].set_title("SON", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original33,  cmap='terrain', ax=axs[2,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.035)
cb.set_label('Evapotransp. [kgm$^{-2}$s$^{-1}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

plt.suptitle('Exp4b-Loam Seasonal Cycle from 1980-2010 Climatology'"\n" "Spatially Uniform Soil Parameters",fontweight='bold',fontsize=14)


# cmap = plt.cm.terrain
# bounds = [-1, 2, 5, 7, 12, 15]
# norm = plt.colors.BoundaryNorm(bounds, cmap.N, extend='both')
# fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
#              cax=ax, orientation='horizontal', label='Some Units')
# ax = plt.subplot(projection=ccrs.PlateCarree())
# ax.coastlines("10m", color="r")
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,7], gridspec_kw={'wspace':.14, 'hspace':.23})
kwargs = {'format': '%.0f'} 
 
axs[0,0].set_title('a',fontweight='bold', fontsize=13, loc='left')
original1=axs[0,0].imshow(sExp4c_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("Season DJF", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

axs[0,1].set_title('b', fontweight='bold',fontsize=13, loc='left')
original2=axs[0,1].imshow(sExp4c_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("Season JJA", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

axs[0,2].set_title('c ',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,2].imshow(sExp4c_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("Season MAM", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

axs[0,3].set_title('d',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,3].imshow(sExp4c_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("Season SON", loc='center',fontweight='bold',size=13)
axs[0,3].grid()

cb =fig.colorbar(original2, cmap='BrBG', ax=axs[0,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.03)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')
################################# Soil Temperature ################################################################
 
axs[1,0].set_title('e',fontweight='bold', fontsize=13, loc='left')
original1=axs[1,0].imshow(sExp4c_tsl[0,:,:].squeeze()-273 , cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[1,0].grid()

axs[1,1].set_title('f', fontweight='bold',fontsize=13, loc='left')
original21=axs[1,1].imshow(sExp4c_tsl[1,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[1,1].grid()

axs[1,2].set_title('g',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,2].imshow(sExp4c_tsl[2,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[1,2].grid()

axs[1,3].set_title('h',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,3].imshow(sExp4c_tsl[3,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,3].set_title("SON", loc='right',fontweight='bold',size=13)
axs[1,3].grid()

cb =fig.colorbar(original21, cmap='RdBu_r', ax=axs[1,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.032)
cb.set_label('Soil Temperature [$^\circ$C]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

##########################################Total Evapotranspiration##############################################

axs[2,0].set_title('i',fontweight='bold', fontsize=13, loc='left')
original1=axs[2,0].imshow(sExp4c_et[0,:,:].squeeze() , cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[2,0].grid()

axs[2,1].set_title('j', fontweight='bold',fontsize=13, loc='left')
original2=axs[2,1].imshow(sExp4c_et[1,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[2,1].grid()

axs[2,2].set_title('k ',fontweight='bold', fontsize=13, loc='left')
original3=axs[2,2].imshow(sExp4c_et[2,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[2,2].grid()

axs[2,3].set_title('l',fontweight='bold', fontsize=13, loc='left')
original33=axs[2,3].imshow(sExp4c_et[3,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,3].set_title("SON", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original33,  cmap='terrain', ax=axs[2,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.035)
cb.set_label('Evapotransp. [kgm$^{-2}$s$^{-1}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

plt.suptitle('Exp4c-Clay Seasonal Cycle from 1980-2010 Climatology'"\n" "Spatially Uniform Soil Parameters",fontweight='bold',fontsize=14)


# cmap = plt.cm.terrain
# bounds = [-1, 2, 5, 7, 12, 15]
# norm = plt.colors.BoundaryNorm(bounds, cmap.N, extend='both')
# fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
#              cax=ax, orientation='horizontal', label='Some Units')
# ax = plt.subplot(projection=ccrs.PlateCarree())
# ax.coastlines("10m", color="r")
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,7], gridspec_kw={'wspace':.14, 'hspace':.23})
kwargs = {'format': '%.0f'} 
 
axs[0,0].set_title('a',fontweight='bold', fontsize=13, loc='left')
original1=axs[0,0].imshow(sExp4d_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("Season DJF", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

axs[0,1].set_title('b', fontweight='bold',fontsize=13, loc='left')
original2=axs[0,1].imshow(sExp4d_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("Season JJA", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

axs[0,2].set_title('c ',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,2].imshow(sExp4d_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("Season MAM", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

axs[0,3].set_title('d',fontweight='bold', fontsize=13, loc='left')
original3=axs[0,3].imshow(sExp4d_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("Season SON", loc='center',fontweight='bold',size=13)
axs[0,3].grid()

cb =fig.colorbar(original2, cmap='BrBG', ax=axs[0,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.03)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')
################################# Soil Temperature ################################################################
 
axs[1,0].set_title('e',fontweight='bold', fontsize=13, loc='left')
original1=axs[1,0].imshow(sExp4d_tsl[0,:,:].squeeze()-273 , cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[1,0].grid()

axs[1,1].set_title('f', fontweight='bold',fontsize=13, loc='left')
original21=axs[1,1].imshow(sExp4d_tsl[1,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[1,1].grid()

axs[1,2].set_title('g',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,2].imshow(sExp4d_tsl[2,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[1,2].grid()

axs[1,3].set_title('h',fontweight='bold', fontsize=13, loc='left')
original3=axs[1,3].imshow(sExp4d_tsl[3,:,:].squeeze()-273, cmap='RdBu_r', interpolation='bilinear', aspect='auto', origin='lower')
#axs[1,3].set_title("SON", loc='right',fontweight='bold',size=13)
axs[1,3].grid()

cb =fig.colorbar(original21, cmap='RdBu_r', ax=axs[1,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.032)
cb.set_label('Soil Temperature [$^\circ$C]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

##########################################Total Evapotranspiration##############################################

axs[2,0].set_title('i',fontweight='bold', fontsize=13, loc='left')
original1=axs[2,0].imshow(sExp4d_et[0,:,:].squeeze() , cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,0].set_title("DJF", loc='right',fontweight='bold',size=13)
axs[2,0].grid()

axs[2,1].set_title('j', fontweight='bold',fontsize=13, loc='left')
original2=axs[2,1].imshow(sExp4d_et[1,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,1].set_title("JJA", loc='right',fontweight='bold',size=13)
axs[2,1].grid()

axs[2,2].set_title('k ',fontweight='bold', fontsize=13, loc='left')
original3=axs[2,2].imshow(sExp4d_et[2,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,2].set_title("MAM", loc='right',fontweight='bold',size=13)
axs[2,2].grid()

axs[2,3].set_title('l',fontweight='bold', fontsize=13, loc='left')
original33=axs[2,3].imshow(sExp4d_et[3,:,:].squeeze(), cmap='terrain', interpolation='bilinear', aspect='auto', origin='lower')
#axs[2,3].set_title("SON", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original33,  cmap='terrain', ax=axs[2,3], orientation='vertical', shrink=1, extend='both',aspect=7, pad=0.035)
cb.set_label('Evapotransp. [kgm$^{-2}$s$^{-1}$]',fontweight='bold', fontsize=9)#.set_label(label='new label',size=15,weight='bold')

plt.suptitle('Exp4d-Silt Seasonal Cycle from 1980-2010 Climatology'"\n" "Spatially Uniform Soil Parameter",fontweight='bold',fontsize=14)


# cmap = plt.cm.terrain
# bounds = [-1, 2, 5, 7, 12, 15]
# norm = plt.colors.BoundaryNorm(bounds, cmap.N, extend='both')
# fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
#              cax=ax, orientation='horizontal', label='Some Units')
# ax = plt.subplot(projection=ccrs.PlateCarree())
# ax.coastlines("10m", color="r")
plt.show()

# %% [markdown]
# ### Monthly Mean Climatology

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,8], gridspec_kw={'wspace':.18, 'hspace':.22})
kwargs = {'format': '%.0f'} 
 
#axs[0,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[0,0].imshow(Exp1_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("January", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

#axs[0,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[0,1].imshow(Exp1_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("February", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

#axs[0,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,2].imshow(Exp1_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("March", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

#axs[0,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,3].imshow(Exp1_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("April", loc='center',fontweight='bold',size=13)
axs[0,3].grid()



#axs[1,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[1,0].imshow(Exp1_mrlsl[4,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,0].set_title("May", loc='center',fontweight='bold',size=13)
axs[1,0].grid()

#axs[1,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[1,1].imshow(Exp1_mrlsl[5,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,1].set_title("June", loc='center',fontweight='bold',size=13)
axs[1,1].grid()

#axs[1,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,2].imshow(Exp1_mrlsl[6,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,2].set_title("July", loc='center',fontweight='bold',size=13)
axs[1,2].grid()

#axs[1,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,3].imshow(Exp1_mrlsl[7,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,3].set_title("August", loc='center',fontweight='bold',size=13)
axs[1,3].grid()



#axs[2,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[2,0].imshow(Exp1_mrlsl[8,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,0].set_title("September", loc='center',fontweight='bold',size=13)
axs[2,0].grid()

#axs[2,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[2,1].imshow(Exp1_mrlsl[9,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,1].set_title("October", loc='center',fontweight='bold',size=13)
axs[2,1].grid()

#axs[2,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,2].imshow(Exp1_mrlsl[10,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,2].set_title("November", loc='center',fontweight='bold',size=13)
axs[2,2].grid()

#axs[2,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,3].imshow(Exp1_mrlsl[11,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,3].set_title("December", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original2, cmap='BrBG', ax=axs.ravel().tolist(), orientation='horizontal', shrink=0.5, extend='both', pad=0.05)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=12)#.set_label(label='new label',size=15,weight='bold')
plt.suptitle('Exp1 Soil Moisture Annual Cycle from 1980-2010 Climatology'"\n" "Identical Soil Parameter Maps",fontweight='bold',fontsize=14)
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,8], gridspec_kw={'wspace':.18, 'hspace':.22})
kwargs = {'format': '%.0f'} 
 
#axs[0,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[0,0].imshow(Exp2_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("January", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

#axs[0,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[0,1].imshow(Exp2_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("February", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

#axs[0,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,2].imshow(Exp2_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("March", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

#axs[0,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,3].imshow(Exp2_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("April", loc='center',fontweight='bold',size=13)
axs[0,3].grid()



#axs[1,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[1,0].imshow(Exp2_mrlsl[4,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,0].set_title("May", loc='center',fontweight='bold',size=13)
axs[1,0].grid()

#axs[1,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[1,1].imshow(Exp2_mrlsl[5,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,1].set_title("June", loc='center',fontweight='bold',size=13)
axs[1,1].grid()

#axs[1,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,2].imshow(Exp2_mrlsl[6,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,2].set_title("July", loc='center',fontweight='bold',size=13)
axs[1,2].grid()

#axs[1,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,3].imshow(Exp2_mrlsl[7,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,3].set_title("August", loc='center',fontweight='bold',size=13)
axs[1,3].grid()



#axs[2,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[2,0].imshow(Exp2_mrlsl[8,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,0].set_title("September", loc='center',fontweight='bold',size=13)
axs[2,0].grid()

#axs[2,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[2,1].imshow(Exp2_mrlsl[9,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,1].set_title("October", loc='center',fontweight='bold',size=13)
axs[2,1].grid()

#axs[2,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,2].imshow(Exp2_mrlsl[10,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,2].set_title("November", loc='center',fontweight='bold',size=13)
axs[2,2].grid()

#axs[2,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,3].imshow(Exp2_mrlsl[11,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,3].set_title("December", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original2, cmap='BrBG', ax=axs.ravel().tolist(), orientation='horizontal', shrink=0.5, extend='both', pad=0.05)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=12)#.set_label(label='new label',size=15,weight='bold')
plt.suptitle('Exp2 Soil Moisture Annual Cycle from 1980-2010 Climatology'"\n" "Identical Soil Texture Maps",fontweight='bold',fontsize=14)
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,8], gridspec_kw={'wspace':.18, 'hspace':.22})
kwargs = {'format': '%.0f'} 
 
#axs[0,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[0,0].imshow(Exp3_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("January", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

#axs[0,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[0,1].imshow(Exp3_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("February", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

#axs[0,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,2].imshow(Exp3_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("March", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

#axs[0,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,3].imshow(Exp3_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("April", loc='center',fontweight='bold',size=13)
axs[0,3].grid()



#axs[1,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[1,0].imshow(Exp3_mrlsl[4,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,0].set_title("May", loc='center',fontweight='bold',size=13)
axs[1,0].grid()

#axs[1,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[1,1].imshow(Exp3_mrlsl[5,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,1].set_title("June", loc='center',fontweight='bold',size=13)
axs[1,1].grid()

#axs[1,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,2].imshow(Exp3_mrlsl[6,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,2].set_title("July", loc='center',fontweight='bold',size=13)
axs[1,2].grid()

#axs[1,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,3].imshow(Exp3_mrlsl[7,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,3].set_title("August", loc='center',fontweight='bold',size=13)
axs[1,3].grid()



#axs[2,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[2,0].imshow(Exp3_mrlsl[8,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,0].set_title("September", loc='center',fontweight='bold',size=13)
axs[2,0].grid()

#axs[2,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[2,1].imshow(Exp3_mrlsl[9,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,1].set_title("October", loc='center',fontweight='bold',size=13)
axs[2,1].grid()

#axs[2,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,2].imshow(Exp3_mrlsl[10,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,2].set_title("November", loc='center',fontweight='bold',size=13)
axs[2,2].grid()

#axs[2,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,3].imshow(Exp3_mrlsl[11,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,3].set_title("December", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original2, cmap='BrBG', ax=axs.ravel().tolist(), orientation='horizontal', shrink=0.5, extend='both', pad=0.05)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=12)#.set_label(label='new label',size=15,weight='bold')
plt.suptitle('Exp3 Soil Moisture Annual Cycle from 1980-2010 Climatology'"\n" "Default Soil Parameter Maps",fontweight='bold',fontsize=14)
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,8], gridspec_kw={'wspace':.18, 'hspace':.22})
kwargs = {'format': '%.0f'} 
 
#axs[0,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[0,0].imshow(Exp4a_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("January", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

#axs[0,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[0,1].imshow(Exp4a_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("February", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

#axs[0,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,2].imshow(Exp4a_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("March", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

#axs[0,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,3].imshow(Exp4a_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("April", loc='center',fontweight='bold',size=13)
axs[0,3].grid()



#axs[1,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[1,0].imshow(Exp4a_mrlsl[4,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,0].set_title("May", loc='center',fontweight='bold',size=13)
axs[1,0].grid()

#axs[1,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[1,1].imshow(Exp4a_mrlsl[5,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,1].set_title("June", loc='center',fontweight='bold',size=13)
axs[1,1].grid()

#axs[1,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,2].imshow(Exp4a_mrlsl[6,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,2].set_title("July", loc='center',fontweight='bold',size=13)
axs[1,2].grid()

#axs[1,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,3].imshow(Exp4a_mrlsl[7,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,3].set_title("August", loc='center',fontweight='bold',size=13)
axs[1,3].grid()



#axs[2,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[2,0].imshow(Exp4a_mrlsl[8,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,0].set_title("September", loc='center',fontweight='bold',size=13)
axs[2,0].grid()

#axs[2,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[2,1].imshow(Exp4a_mrlsl[9,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,1].set_title("October", loc='center',fontweight='bold',size=13)
axs[2,1].grid()

#axs[2,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,2].imshow(Exp4a_mrlsl[10,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,2].set_title("November", loc='center',fontweight='bold',size=13)
axs[2,2].grid()

#axs[2,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,3].imshow(Exp4a_mrlsl[11,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,3].set_title("December", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original2, cmap='BrBG', ax=axs.ravel().tolist(), orientation='horizontal', shrink=0.5, extend='both', pad=0.05)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=12)#.set_label(label='new label',size=15,weight='bold')
plt.suptitle('Exp4a-Loamy Seasonal Cycle from 1980-2010 Climatology'"\n" "Spatially Uniform Soil Parameter",fontweight='bold',fontsize=14)
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,8], gridspec_kw={'wspace':.18, 'hspace':.22})
kwargs = {'format': '%.0f'} 
 
#axs[0,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[0,0].imshow(Exp4b_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("January", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

#axs[0,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[0,1].imshow(Exp4b_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("February", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

#axs[0,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,2].imshow(Exp4b_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("March", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

#axs[0,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,3].imshow(Exp4b_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("April", loc='center',fontweight='bold',size=13)
axs[0,3].grid()



#axs[1,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[1,0].imshow(Exp4b_mrlsl[4,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,0].set_title("May", loc='center',fontweight='bold',size=13)
axs[1,0].grid()

#axs[1,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[1,1].imshow(Exp4b_mrlsl[5,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,1].set_title("June", loc='center',fontweight='bold',size=13)
axs[1,1].grid()

#axs[1,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,2].imshow(Exp4b_mrlsl[6,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,2].set_title("July", loc='center',fontweight='bold',size=13)
axs[1,2].grid()

#axs[1,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,3].imshow(Exp4b_mrlsl[7,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,3].set_title("August", loc='center',fontweight='bold',size=13)
axs[1,3].grid()



#axs[2,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[2,0].imshow(Exp4b_mrlsl[8,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,0].set_title("September", loc='center',fontweight='bold',size=13)
axs[2,0].grid()

#axs[2,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[2,1].imshow(Exp4b_mrlsl[9,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,1].set_title("October", loc='center',fontweight='bold',size=13)
axs[2,1].grid()

#axs[2,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,2].imshow(Exp4b_mrlsl[10,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,2].set_title("November", loc='center',fontweight='bold',size=13)
axs[2,2].grid()

#axs[2,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,3].imshow(Exp4b_mrlsl[11,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,3].set_title("December", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original2, cmap='BrBG', ax=axs.ravel().tolist(), orientation='horizontal', shrink=0.5, extend='both', pad=0.05)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=12)#.set_label(label='new label',size=15,weight='bold')
plt.suptitle('Exp4b-Loam Soil Moisture Annual Cycle from 1980-2010 Climatology'"\n" "Spatially Uniform Soil Parameter",fontweight='bold',fontsize=14)
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,8], gridspec_kw={'wspace':.18, 'hspace':.22})
kwargs = {'format': '%.0f'} 
 
#axs[0,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[0,0].imshow(Exp4c_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("January", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

#axs[0,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[0,1].imshow(Exp4c_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("February", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

#axs[0,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,2].imshow(Exp4c_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("March", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

#axs[0,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,3].imshow(Exp4c_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("April", loc='center',fontweight='bold',size=13)
axs[0,3].grid()



#axs[1,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[1,0].imshow(Exp4c_mrlsl[4,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,0].set_title("May", loc='center',fontweight='bold',size=13)
axs[1,0].grid()

#axs[1,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[1,1].imshow(Exp4c_mrlsl[5,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,1].set_title("June", loc='center',fontweight='bold',size=13)
axs[1,1].grid()

#axs[1,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,2].imshow(Exp4c_mrlsl[6,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,2].set_title("July", loc='center',fontweight='bold',size=13)
axs[1,2].grid()

#axs[1,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,3].imshow(Exp4c_mrlsl[7,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,3].set_title("August", loc='center',fontweight='bold',size=13)
axs[1,3].grid()



#axs[2,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[2,0].imshow(Exp4c_mrlsl[8,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,0].set_title("September", loc='center',fontweight='bold',size=13)
axs[2,0].grid()

#axs[2,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[2,1].imshow(Exp4c_mrlsl[9,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,1].set_title("October", loc='center',fontweight='bold',size=13)
axs[2,1].grid()

#axs[2,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,2].imshow(Exp4c_mrlsl[10,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,2].set_title("November", loc='center',fontweight='bold',size=13)
axs[2,2].grid()

#axs[2,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,3].imshow(Exp4c_mrlsl[11,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,3].set_title("December", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original2, cmap='BrBG', ax=axs.ravel().tolist(), orientation='horizontal', shrink=0.5, extend='both', pad=0.05)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=12)#.set_label(label='new label',size=15,weight='bold')
plt.suptitle('Exp4c-Clay Soil Moisture Annual Cycle from 1980-2010 Climatology'"\n" "Spatially Uniform Soil Parameter",fontweight='bold',fontsize=14)
plt.show()

# %%
fig, axs = plt.subplots(nrows=3,ncols=4, sharex=True, figsize=[15,8], gridspec_kw={'wspace':.18, 'hspace':.22})
kwargs = {'format': '%.0f'} 
 
#axs[0,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[0,0].imshow(Exp4d_mrlsl[0,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,0].set_title("January", loc='center',fontweight='bold',size=13)
axs[0,0].grid()

#axs[0,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[0,1].imshow(Exp4d_mrlsl[1,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,1].set_title("February", loc='center',fontweight='bold',size=13)
axs[0,1].grid()

#axs[0,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,2].imshow(Exp4d_mrlsl[2,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,2].set_title("March", loc='center',fontweight='bold',size=13)
axs[0,2].grid()

#axs[0,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[0,3].imshow(Exp4d_mrlsl[3,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[0,3].set_title("April", loc='center',fontweight='bold',size=13)
axs[0,3].grid()



#axs[1,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[1,0].imshow(Exp4d_mrlsl[4,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,0].set_title("May", loc='center',fontweight='bold',size=13)
axs[1,0].grid()

#axs[1,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[1,1].imshow(Exp4d_mrlsl[5,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,1].set_title("June", loc='center',fontweight='bold',size=13)
axs[1,1].grid()

#axs[1,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,2].imshow(Exp4d_mrlsl[6,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,2].set_title("July", loc='center',fontweight='bold',size=13)
axs[1,2].grid()

#axs[1,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[1,3].imshow(Exp4d_mrlsl[7,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[1,3].set_title("August", loc='center',fontweight='bold',size=13)
axs[1,3].grid()



#axs[2,0].set_title('a) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original1=axs[2,0].imshow(Exp4d_mrlsl[8,:,:].squeeze() , cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,0].set_title("September", loc='center',fontweight='bold',size=13)
axs[2,0].grid()

#axs[2,1].set_title('b) SM-Exp-1 (1980 - 2010)', fontweight='bold',fontsize=11, loc='left')
original2=axs[2,1].imshow(Exp4d_mrlsl[9,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,1].set_title("October", loc='center',fontweight='bold',size=13)
axs[2,1].grid()

#axs[2,2].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,2].imshow(Exp4d_mrlsl[10,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,2].set_title("November", loc='center',fontweight='bold',size=13)
axs[2,2].grid()

#axs[2,3].set_title('c) SM-Exp-1 (1980 - 2010)',fontweight='bold', fontsize=11, loc='left')
original3=axs[2,3].imshow(Exp4d_mrlsl[11,:,:].squeeze(), cmap='BrBG', interpolation='bilinear', aspect='auto', origin='lower')
axs[2,3].set_title("December", loc='center',fontweight='bold',size=13)
axs[2,3].grid()

cb =plt.colorbar(original2, cmap='BrBG', ax=axs.ravel().tolist(), orientation='horizontal', shrink=0.5, extend='both', pad=0.05)
cb.set_label('Soil Moisture [kgm$^{-2}}$]',fontweight='bold', fontsize=12)#.set_label(label='new label',size=15,weight='bold')
plt.suptitle('Exp4d-Silt Soil Moisture Annual Cycle from 1980-2010 Climatology'"\n" "Spatially Uniform Soil Parameter",fontweight='bold',fontsize=14)
plt.show()
